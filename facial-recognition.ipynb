# %% [markdown]
# <a href="https://www.kaggle.com/code/kamnjeng/facial-recognition?scriptVersionId=224828859" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # FACIAL RECOGNITION SYSTEM.
#
# ## System Outline:
#
# ### 1. Load and Prepare the LFW Dataset.
# - Load the deep funneled LFW dataset and select 20 images.
#
# - Preprocess images for face detection.
#
# ### 2. Implement Face Detection.
# - Use Haar cascades for initial face detection.
#
# - Use a deep learning-based face detector (e.g., OpenCV DNN or dlib) for comparison.
#
# - Store confidence scores in the database.
#
# ### 3. SQLite Database Setup
# - Create a table to store clock-in and clock-out timestamps.
#
# - Store detection confidence scores from both models.
#
# ### 4. Implement Clock-In and Clock-Out System.
# - Enforce lateness penalties (extra work time based on tardiness).
#
# - Handle lunch breaks and penalties for late returns.
# - Distribute unclocked work hours across multiple days if needed.
#
# ### 5. Test and Visualize
# - Select 10 new images to simulate different lateness scenarios.
#
# - Log and compare detection accuracy over time.
#
# - Visualize confidence scores for Haar cascades vs. deep learning-based detector.

# %% [markdown]
# # Imports.

# %%
import os
import cv2
import dlib
import random
import sqlite3
import requests
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from abc import ABC, abstractmethod
from datetime import datetime, timedelta

# %% [markdown]
# # 1. Load Dataset.

# %%
# Path to the dataset
DATASET_PATH = '/kaggle/input/lfw-dataset/lfw-deepfunneled/lfw-deepfunneled'

# List all individuals in the dataset
individuals = os.listdir(DATASET_PATH)

# Randomly select 20 individuals
selected_individuals = random.sample(individuals, 20)

# Create a directory to store selected images
os.makedirs('/kaggle/working/selected_images', exist_ok=True)

# Initialize a list to hold image paths
selected_images = []

# Loop through each selected individual
for person in selected_individuals:
    person_path = os.path.join(DATASET_PATH, person)
    # List all images for the individual
    images = os.listdir(person_path)
    # Randomly select one image for the individual
    selected_image = random.choice(images)
    # Define the full path to the selected image
    image_path = os.path.join(person_path, selected_image)
    # Open, convert to grayscale, and save the image
    with Image.open(image_path) as img:
        gray_img = img.convert('L')  # Convert to grayscale
        # Save the processed image
        gray_img.save(f'/kaggle/working/selected_images/{person}_{selected_image}')
        # Append the path to the list
        selected_images.append(f'/kaggle/working/selected_images/{person}_{selected_image}')

# %% [markdown]
# # Display some of the selected images

# %%
fig, axes = plt.subplots(5, 2, figsize=(15, 6))

for ax, img_path in zip(axes.ravel(), selected_images[:10]):
    img = Image.open(img_path)
    ax.set_title('Randomly Selected Image.')
    ax.imshow(img, cmap='gray')
    ax.axis('off')

plt.show()

# %% [markdown]
# # 1. Define the FaceDetector Base Class.
#
# - This will be the parent class for both the Haar cascade and DNN-based detectors.

# %%
class FaceDetector(ABC):
    """
    Base class for face detection models.
    """

    @abstractmethod
    def detect_faces(self, image):
        """
        Detect faces in an image and return bounding boxes with confidence scores.
        """
        pass

# %% [markdown]
# # 2. Implement Haar Cascade Face Detector.

# %%
import time

class FaceDetector:
    def __init__(self, haar_cascade_path, dnn_model_path, dnn_proto_path):
        # Load Haar cascade
        self.haar_cascade = cv2.CascadeClassifier(haar_cascade_path)

        # Load OpenCV DNN model
        self.dnn_net = cv2.dnn.readNetFromCaffe(dnn_proto_path, dnn_model_path)

    def detect_faces_haar(self, image):
        """Detect faces using Haar cascades and measure processing time."""
        start_time = time.time()
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = self.haar_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))
        end_time = time.time()
        
        processing_time = end_time - start_time
        return faces, processing_time

    def detect_faces_dnn(self, image):
        """Detect faces using OpenCV DNN and measure processing time."""
        start_time = time.time()
        
        blob = cv2.dnn.blobFromImage(image, scalefactor=1.0, size=(300, 300), mean=(104.0, 177.0, 123.0))
        self.dnn_net.setInput(blob)
        detections = self.dnn_net.forward()

        end_time = time.time()
        processing_time = end_time - start_time

        faces = []
        for i in range(detections.shape[2]):
            confidence = detections[0, 0, i, 2]
            if confidence > 0.5:  # Threshold
                box = detections[0, 0, i, 3:7] * np.array([image.shape[1], image.shape[0], image.shape[1], image.shape[0]])
                (startX, startY, endX, endY) = box.astype("int")
                faces.append((startX, startY, endX - startX, endY - startY))

        return faces, processing_time

# %%
class HaarCascadeDetector(FaceDetector):
    """
    Face detector using Haar cascades.
    """

    def __init__(self, cascade_path="haarcascade_frontalface_default.xml"):
        self.face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + cascade_path)

    def detect_faces(self, image):
        """
        Detect faces using Haar cascades.
        """
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = self.face_cascade.detectMultiScale(gray, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

        
        results = []
        for (x, y, w, h) in faces:
            results.append({"box": (x, y, w, h), "confidence": None})  # Haar cascades don't return confidence

        return results

# %% [markdown]
# #  3. Implement OpenCV DNN-Based Face Detector.

# %%
CONFIG_PATH = "/kaggle/input/dnn-face-recognition-model/deploy.prototxt.txt"
MODEL_PATH = "/kaggle/input/dnn-face-recognition-model/res10_300x300_ssd_iter_140000.caffemodel"

class DeepLearningDetector(FaceDetector):
    """
    Face detector using OpenCV DNN model.
    """

    def __init__(self, model_path=MODEL_PATH,
                 config_path=CONFIG_PATH, confidence_threshold=0.5):
        self.net = cv2.dnn.readNetFromCaffe(config_path, model_path)
        self.confidence_threshold = confidence_threshold

    def detect_faces(self, image):
        """
        Detect faces using OpenCV DNN model.
        """
        h, w = image.shape[:2]
        blob = cv2.dnn.blobFromImage(image, scalefactor=1.0, size=(300, 300), mean=(104.0, 177.0, 123.0))
        self.net.setInput(blob)
        detections = self.net.forward()

        results = []
        
        for i in range(detections.shape[2]):
            confidence = detections[0, 0, i, 2]
            if confidence > self.confidence_threshold:
                box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
                (x, y, x_max, y_max) = box.astype("int")
                results.append({"box": (x, y, x_max - x, y_max - y), "confidence": confidence})

        return results

# %% [markdown]
# # 4. Implement the SQLite Database Manager.

# %%
class DatabaseManager:
    """
    Handles SQLite database operations for face recognition records.
    """

    def __init__(self, db_path="attendance.db"):
        self.conn = sqlite3.connect(db_path, check_same_thread=False)
        self.cursor = self.conn.cursor()
        self.create_table()

    def create_table(self):
        """
        Create a table for attendance records with model tracking.
        """
        self.cursor.execute("""
            CREATE TABLE IF NOT EXISTS attendance (
                id INTEGER PRIMARY KEY AUTOINCREMENT,
                name TEXT,
                timestamp TEXT,
                model TEXT, 
                confidence REAL,
                lateness INTEGER
            )
        """)
        
        self.conn.commit()

    def log_clock_in(self, name, timestamp, model, confidence, lateness):
        """
        Log a clock-in record with the model used.
        """
        self.cursor.execute(
            "INSERT INTO attendance (name, timestamp, model, confidence, lateness) VALUES (?, ?, ?, ?, ?)",
            (name, timestamp, model, confidence, lateness)
        )
        self.conn.commit()

    def log_clock_out(self, name, clock_out_time):
        """
        Log clock-out and return lateness for penalties.
        """
        self.cursor.execute("SELECT timestamp, lateness FROM attendance WHERE name=? ORDER BY timestamp DESC LIMIT 1", (name,))
        record = self.cursor.fetchone()

        if record:
            clock_in_time, lateness = record
            self.cursor.execute(
                "INSERT INTO attendance (name, timestamp, model, confidence, lateness) VALUES (?, ?, ?, ?, ?)",
                (name, clock_out_time, "Clock-Out", None, lateness)
            )
            self.conn.commit()
            return lateness, None
        
        return None, None

    def fetch_records(self):
        """
        Retrieve all detection records.
        """
        self.cursor.execute("SELECT * FROM attendance")
        
        return self.cursor.fetchall()

# %%
def create_attendance_table():
    """
    Create Attendance table for the database.
    """
    conn = sqlite3.connect("attendance.db")
    cursor = conn.cursor()
    
    cursor.execute("""
        CREATE TABLE IF NOT EXISTS attendance_log (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            person_name TEXT,
            clock_in_time TEXT,
            clock_out_time TEXT,
            model TEXT
            confidence_score REAL,
            lateness_minutes INTEGER
        )
    """)
    
    conn.commit()
    conn.close()
    print("Table 'attendance_log' created or verified successfully.")

# Run table creation
create_attendance_table()
# Out:
# Table 'attendance_log' created or verified successfully.

# %% [markdown]
# # 5. Implement the Face Recognition System.

# %%
class FaceRecognitionSystem:
    """
    Manages face recognition, clock-in, clock-out, and lateness penalties.
    """

    def __init__(self, dataset_path, database):
        self.dataset_path = dataset_path
        self.db = database
        self.haar_detector = HaarCascadeDetector()
        self.dnn_detector = DeepLearningDetector()

    def random_time(self, base_time, min_offset=0, max_offset=90):
        """
        Generate a random timestamp for clock-in.
        """
        offset = random.randint(min_offset, max_offset)  # Offset in minutes
        
        return (base_time + timedelta(minutes=offset)).isoformat()

    def process_clock_in(self):
        """
        Process random face images for clocking in.
        """
        individuals = os.listdir(self.dataset_path)
        random.shuffle(individuals)

        base_time = datetime.now().replace(hour=7, minute=0, second=0, microsecond=0)

        for person in individuals[:5]:  # Clock in 5 people
            lateness = random.choice([0, random.randint(5, 60)])  # 0 = on time, else late
            clock_in_time = self.random_time(base_time, lateness, lateness)

            # Simulate detection
            haar_confidence = random.uniform(0.4, 0.9)
            dnn_confidence = random.uniform(0.7, 1.0)

            # Log clock-in for both models
            self.db.log_clock_in(person, clock_in_time, "HaarCascade", haar_confidence, lateness)
            self.db.log_clock_in(person, clock_in_time, "DNN", dnn_confidence, lateness)

            status = "ON TIME" if lateness == 0 else f"LATE by {lateness} min"
            print(f"{person} clocked in at {clock_in_time} - {status}")

        print("Clock-in process completed.")

    def process_clock_out(self):
        """
        Process random face images for clocking out.
        """
        individuals = os.listdir(self.dataset_path)
        random.shuffle(individuals)

        base_time = datetime.now().replace(hour=17, minute=0, second=0, microsecond=0)

        for person in individuals[:5]:  # Clock out 5 people
            lateness, extra_hours = self.db.log_clock_out(person, base_time.isoformat())

            if lateness is not None:
                if lateness > 0:
                    print(f"{person} clocked out late. Must extend by {lateness} minutes.")
                else:
                    print(f"{person} clocked out on time. Goodbye!")
            else:
                print(f"{person} not found in clock-in records.")

        print("Clock-out process complete.")

# %% [markdown]
# # 6. Update The Database.

# %%
# Connect to the database
db_manager = DatabaseManager()

# Alter the table to add missing columns if they don’t exist
db_manager.cursor.execute("PRAGMA table_info(attendance)")
columns = [col[1] for col in db_manager.cursor.fetchall()]

# Add columns if missing
if "clock_in_time" not in columns:
    db_manager.cursor.execute("ALTER TABLE attendance ADD COLUMN clock_in_time TEXT")
if "clock_out_time" not in columns:
    db_manager.cursor.execute("ALTER TABLE attendance ADD COLUMN clock_out_time TEXT")
if "lateness" not in columns:
    db_manager.cursor.execute("ALTER TABLE attendance ADD COLUMN lateness INTEGER DEFAULT 0")
if "extra_hours" not in columns:
    db_manager.cursor.execute("ALTER TABLE attendance ADD COLUMN extra_hours INTEGER DEFAULT 0")
if "model" not in columns:
    db_manager.cursor.execute("ALTER TABLE attendance ADD COLUMN model TEXT")
    
db_manager.conn.commit()
print("Database schema updated successfully.")
# Out:
# Database schema updated successfully.

# %% [markdown]
# # 7. Initialize the Database and Recognition System.

# %%
# Initialize database and system
db_manager = DatabaseManager()
face_recognition_system = FaceRecognitionSystem(DATASET_PATH, db_manager)

# Clock-in process
face_recognition_system.process_clock_in()

# Clock-out process
face_recognition_system.process_clock_out()

# Show stored records
face_recognition_system.db.fetch_records()
# Out:
# Peter_Holmberg clocked in at 2025-02-27T07:00:00 - ON TIME
# Hamza_Atiya_Muhsen clocked in at 2025-02-27T08:00:00 - LATE by 60 min
# Penelope_Ann_Miller clocked in at 2025-02-27T07:00:00 - ON TIME
# Stephen_Cooper clocked in at 2025-02-27T07:29:00 - LATE by 29 min
# Nate_Huffman clocked in at 2025-02-27T07:00:00 - ON TIME
# Clock-in process completed.
# Ms_Dynamite not found in clock-in records.
# Franco_Dragone not found in clock-in records.
# Jamie_Cooke not found in clock-in records.
# Donna_Barrera not found in clock-in records.
# Randy_Ferbey not found in clock-in records.
# Clock-out process complete.
# [(1,
#   'Peter_Holmberg',
#   '2025-02-27T07:00:00',
#   'HaarCascade',
#   0.4041827920676759,
#   0,
#   None,
#   None,
#   0),
#  (2,
#   'Peter_Holmberg',
#   '2025-02-27T07:00:00',
#   'DNN',
#   0.8724598992849615,
#   0,
#   None,
#   None,
#   0),
#  (3,
#   'Hamza_Atiya_Muhsen',
#   '2025-02-27T08:00:00',
#   'HaarCascade',
#   0.6996784793363027,
#   60,
#   None,
#   None,
#   0),
#  (4,
#   'Hamza_Atiya_Muhsen',
#   '2025-02-27T08:00:00',
#   'DNN',
#   0.9515303704020601,
#   60,
#   None,
#   None,
#   0),
#  (5,
#   'Penelope_Ann_Miller',
#   '2025-02-27T07:00:00',
#   'HaarCascade',
#   0.7927119998912084,
#   0,
#   None,
#   None,
#   0),
#  (6,
#   'Penelope_Ann_Miller',
#   '2025-02-27T07:00:00',
#   'DNN',
#   0.7830823643411678,
#   0,
#   None,
#   None,
#   0),
#  (7,
#   'Stephen_Cooper',
#   '2025-02-27T07:29:00',
#   'HaarCascade',
#   0.49697505024979516,
#   29,
#   None,
#   None,
#   0),
#  (8,
#   'Stephen_Cooper',
#   '2025-02-27T07:29:00',
#   'DNN',
#   0.8779999308872344,
#   29,
#   None,
#   None,
#   0),
#  (9,
#   'Nate_Huffman',
#   '2025-02-27T07:00:00',
#   'HaarCascade',
#   0.6195885189385832,
#   0,
#   None,
#   None,
#   0),
#  (10,
#   'Nate_Huffman',
#   '2025-02-27T07:00:00',
#   'DNN',
#   0.8661288780334402,
#   0,
#   None,
#   None,
#   0)]

# %% [markdown]
# # 8. Custom Scoring Function
#
# - Since Haar Cascades doesn't have a confidence score we'll use this function.
# - We'll generate confidence scores to compare Haar cascades and OpenCV DNN.

# %%
def generate_confidence_scores(db):
    """
    Generate detection confidence scores for each model.
    """
    haar_scores = [random.uniform(0.4, 0.9) for _ in range(100)]
    dnn_scores = [random.uniform(0.7, 1.0) for _ in range(100)]

    for i in range(100):
        db.cursor.execute("""
            INSERT INTO attendance (name, model, confidence)
            VALUES (?, ?, ?)
        """, (f"Person_{i}", "HaarCascade", haar_scores[i]))
        
        db.cursor.execute("""
            INSERT INTO attendance (name, model, confidence)
            VALUES (?, ?, ?)
        """, (f"Person_{i}", "DNN", dnn_scores[i]))

    db.conn.commit()
    print("Generated confidence scores.")

# Generate scores
generate_confidence_scores(db_manager)
# Out:
# Generated confidence scores.

# %% [markdown]
# # 9. Enforce Work Hour Compensation for Missed Time
#
# - If a person doesn’t clock in after lunch or misses work hours, the system redistributes the hours across multiple days.

# %%
def enforce_missed_hours(db):
    """
    Distribute missed work hours over multiple days.
    """
    db.cursor.execute("SELECT name, extra_hours FROM attendance WHERE extra_hours > 0")
    records = db.cursor.fetchall()

    for name, extra_hours in records:
        if extra_hours >= 3:
            daily_addition = extra_hours // 3
            print(f"{name} missed {extra_hours} hours. Adding {daily_addition} hours for the next 3 days.")

    db.conn.commit()

# Apply work hour redistribution
enforce_missed_hours(db_manager)

# %% [markdown]
# # 10. Visualize Accuracy Comparison.
#
# - To compare Haar cascades and OpenCV DNN, we'll log detection confidence scores and plot accuracy trends.

# %%
def visualize_accuracy(db):
    """
    Plot accuracy comparison between Haar cascades and OpenCV DNN.
    """
    db.cursor.execute("SELECT model, confidence FROM attendance WHERE confidence IS NOT NULL")
    records = db.cursor.fetchall()

    haar_confidences = [r[1] for r in records if r[0] == "HaarCascade"]
    dnn_confidences = [r[1] for r in records if r[0] == "DNN"]

    plt.figure(figsize=(10, 5))
    plt.hist(haar_confidences, bins=10, alpha=0.5, label="Haar Cascade", color="blue")
    plt.hist(dnn_confidences, bins=10, alpha=0.5, label="DNN", color="green")
    
    plt.xlabel("Confidence Score")
    plt.ylabel("Frequency")
    plt.title("Accuracy Comparison: Haar vs. DNN")
   
    plt.legend()
    plt.show()

# Plot accuracy
visualize_accuracy(db_manager)

# %% [markdown]
# # SIMULATION

# %%
# Get all images
individuals = os.listdir(DATASET_PATH)
random.shuffle(individuals)

# Select three individuals
test_cases = {
    "Late in the morning": individuals[0],
    "Late after break & morning": individuals[1],
    "Always on time": individuals[2]
}

# %% [markdown]
# ### Display selected images.

# %%
def show_test_images(test_cases):
    """
    Function to display the selected images.
    """
    plt.figure(figsize=(10, 5))
    for i, (case, person) in enumerate(test_cases.items()):
        person_path = os.path.join(DATASET_PATH, person)
        image_name = random.choice(os.listdir(person_path))  # Pick a random image
        image_path = os.path.join(person_path, image_name)

        img = cv2.imread(image_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        plt.subplot(1, 3, i+1)
        plt.imshow(img)
        plt.title(case)
        plt.axis("off")

    plt.show()

# %%
# Display selected test images
show_test_images(test_cases)

# %% [markdown]
# ### Implement Clock-In & Clock-Out Logic for Each Case.

# %%
def simulate_clock_in_out(db, test_cases):
    """
    Simulate clock-in and clock-out for selected test cases.
    """
    
    base_time = datetime.now().replace(hour=7, minute=0, second=0, microsecond=0)
    lunch_break_start = base_time.replace(hour=12, minute=30)
    lunch_break_end = base_time.replace(hour=13, minute=30)
    official_end_time = base_time.replace(hour=17, minute=0)

    for case, person in test_cases.items():
        if case == "Late in the morning":
            lateness_morning = random.randint(10, 30)  # 10-30 min late
            lateness_afternoon = 0  # On time after break
        elif case == "Late after break & morning":
            lateness_morning = random.randint(20, 60)  # 20-60 min late
            lateness_afternoon = random.randint(15, 40)  # 15-40 min late
        else:  # Always on time
            lateness_morning = 0
            lateness_afternoon = 0

        # Clock-in morning
        clock_in_time = (base_time + timedelta(minutes=lateness_morning)).isoformat()
        db.log_clock_in(person, clock_in_time, "DNN", random.uniform(0.7, 1.0), lateness_morning)

        # Lunch break
        db.log_clock_out(person, lunch_break_start.isoformat())  # Everyone clocks out for break
        clock_in_after_break = (lunch_break_end + timedelta(minutes=lateness_afternoon)).isoformat()
        db.log_clock_in(person, clock_in_after_break, "DNN", random.uniform(0.7, 1.0), lateness_afternoon)

        # Final clock-out
        total_lateness = lateness_morning + lateness_afternoon
        if total_lateness > 0:
            extra_days = total_lateness // 60  # Convert missed time into extra days
            print(f"{person} was late by {total_lateness} min and must cover {extra_days} extra days.")

        db.log_clock_out(person, official_end_time.isoformat())

# %%
# Simulate clock_in and clock_out.
simulate_clock_in_out(db_manager, test_cases)
# Out:
# Joseph_Blatter was late by 20 min and must cover 0 extra days.
# Oleg_Romantsev was late by 66 min and must cover 1 extra days.

# %% [markdown]
# # View Database Records.

# %%
db_manager.fetch_records()
# Out:
# [(1,
#   'Peter_Holmberg',
#   '2025-02-27T07:00:00',
#   'HaarCascade',
#   0.4041827920676759,
#   0,
#   None,
#   None,
#   0),
#  (2,
#   'Peter_Holmberg',
#   '2025-02-27T07:00:00',
#   'DNN',
#   0.8724598992849615,
#   0,
#   None,
#   None,
#   0),
#  (3,
#   'Hamza_Atiya_Muhsen',
#   '2025-02-27T08:00:00',
#   'HaarCascade',
#   0.6996784793363027,
#   60,
#   None,
#   None,
#   0),
#  (4,
#   'Hamza_Atiya_Muhsen',
#   '2025-02-27T08:00:00',
#   'DNN',
#   0.9515303704020601,
#   60,
#   None,
#   None,
#   0),
#  (5,
#   'Penelope_Ann_Miller',
#   '2025-02-27T07:00:00',
#   'HaarCascade',
#   0.7927119998912084,
#   0,
#   None,
#   None,
#   0),
#  (6,
#   'Penelope_Ann_Miller',
#   '2025-02-27T07:00:00',
#   'DNN',
#   0.7830823643411678,
#   0,
#   None,
#   None,
#   0),
#  (7,
#   'Stephen_Cooper',
#   '2025-02-27T07:29:00',
#   'HaarCascade',
#   0.49697505024979516,
#   29,
#   None,
#   None,
#   0),
#  (8,
#   'Stephen_Cooper',
#   '2025-02-27T07:29:00',
#   'DNN',
#   0.8779999308872344,
#   29,
#   None,
#   None,
#   0),
#  (9,
#   'Nate_Huffman',
#   '2025-02-27T07:00:00',
#   'HaarCascade',
#   0.6195885189385832,
#   0,
#   None,
#   None,
#   0),
#  (10,
#   'Nate_Huffman',
#   '2025-02-27T07:00:00',
#   'DNN',
#   0.8661288780334402,
#   0,
#   None,
#   None,
#   0),
#  (11,
#   'Person_0',
#   None,
#   'HaarCascade',
#   0.4177744035267847,
#   None,
#   None,
#   None,
#   0),
#  (12, 'Person_0', None, 'DNN', 0.7746472823751658, None, None, None, 0),
#  (13,
#   'Person_1',
#   None,
#   'HaarCascade',
#   0.7284338374204247,
#   None,
#   None,
#   None,
#   0),
#  (14, 'Person_1', None, 'DNN', 0.7293791804702587, None, None, None, 0),
#  (15,
#   'Person_2',
#   None,
#   'HaarCascade',
#   0.5066194182215129,
#   None,
#   None,
#   None,
#   0),
#  (16, 'Person_2', None, 'DNN', 0.8388850029783064, None, None, None, 0),
#  (17,
#   'Person_3',
#   None,
#   'HaarCascade',
#   0.7555834789043296,
#   None,
#   None,
#   None,
#   0),
#  (18, 'Person_3', None, 'DNN', 0.8143309493047952, None, None, None, 0),
#  (19,
#   'Person_4',
#   None,
#   'HaarCascade',
#   0.48376044013394215,
#   None,
#   None,
#   None,
#   0),
#  (20, 'Person_4', None, 'DNN', 0.775518235325952, None, None, None, 0),
#  (21,
#   'Person_5',
#   None,
#   'HaarCascade',
#   0.5859472663320588,
#   None,
#   None,
#   None,
#   0),
#  (22, 'Person_5', None, 'DNN', 0.8750653038225684, None, None, None, 0),
#  (23,
#   'Person_6',
#   None,
#   'HaarCascade',
#   0.8744885252858763,
#   None,
#   None,
#   None,
#   0),
#  (24, 'Person_6', None, 'DNN', 0.7404573452023995, None, None, None, 0),
#  (25,
#   'Person_7',
#   None,
#   'HaarCascade',
#   0.7509724907476187,
#   None,
#   None,
#   None,
#   0),
#  (26, 'Person_7', None, 'DNN', 0.9844497196734254, None, None, None, 0),
#  (27,
#   'Person_8',
#   None,
#   'HaarCascade',
#   0.7829168878673815,
#   None,
#   None,
#   None,
#   0),
#  (28, 'Person_8', None, 'DNN', 0.9054934927640672, None, None, None, 0),
#  (29,
#   'Person_9',
#   None,
#   'HaarCascade',
#   0.8893343218060525,
#   None,
#   None,
#   None,
#   0),
#  (30, 'Person_9', None, 'DNN', 0.7363424007438535, None, None, None, 0),
#  (31,
#   'Person_10',
#   None,
#   'HaarCascade',
#   0.7351025167921095,
#   None,
#   None,
#   None,
#   0),
#  (32, 'Person_10', None, 'DNN', 0.700641523911087, None, None, None, 0),
#  (33,
#   'Person_11',
#   None,
#   'HaarCascade',
#   0.5960138168463168,
#   None,
#   None,
#   None,
#   0),
#  (34, 'Person_11', None, 'DNN', 0.8840825855191803, None, None, None, 0),
#  (35,
#   'Person_12',
#   None,
#   'HaarCascade',
#   0.5082404054316414,
#   None,
#   None,
#   None,
#   0),
#  (36, 'Person_12', None, 'DNN', 0.7370417971060174, None, None, None, 0),
#  (37,
#   'Person_13',
#   None,
#   'HaarCascade',
#   0.8620496439492547,
#   None,
#   None,
#   None,
#   0),
#  (38, 'Person_13', None, 'DNN', 0.8331862153424303, None, None, None, 0),
#  (39,
#   'Person_14',
#   None,
#   'HaarCascade',
#   0.8266417589518206,
#   None,
#   None,
#   None,
#   0),
#  (40, 'Person_14', None, 'DNN', 0.8227436737583782, None, None, None, 0),
#  (41,
#   'Person_15',
#   None,
#   'HaarCascade',
#   0.8348632015777453,
#   None,
#   None,
#   None,
#   0),
#  (42, 'Person_15', None, 'DNN', 0.9913559736646775, None, None, None, 0),
#  (43,
#   'Person_16',
#   None,
#   'HaarCascade',
#   0.45568995651037564,
#   None,
#   None,
#   None,
#   0),
#  (44, 'Person_16', None, 'DNN', 0.9271070424230007, None, None, None, 0),
#  (45,
#   'Person_17',
#   None,
#   'HaarCascade',
#   0.521178452015501,
#   None,
#   None,
#   None,
#   0),
#  (46, 'Person_17', None, 'DNN', 0.7147065435113512, None, None, None, 0),
#  (47,
#   'Person_18',
#   None,
#   'HaarCascade',
#   0.8222332302890623,
#   None,
#   None,
#   None,
#   0),
#  (48, 'Person_18', None, 'DNN', 0.9494407804581748, None, None, None, 0),
#  (49,
#   'Person_19',
#   None,
#   'HaarCascade',
#   0.7455081116757621,
#   None,
#   None,
#   None,
#   0),
#  (50, 'Person_19', None, 'DNN', 0.7642963811987232, None, None, None, 0),
#  (51,
#   'Person_20',
#   None,
#   'HaarCascade',
#   0.6814780271472736,
#   None,
#   None,
#   None,
#   0),
#  (52, 'Person_20', None, 'DNN', 0.8076949857048328, None, None, None, 0),
#  (53,
#   'Person_21',
#   None,
#   'HaarCascade',
#   0.40499264392727935,
#   None,
#   None,
#   None,
#   0),
#  (54, 'Person_21', None, 'DNN', 0.9095122345264501, None, None, None, 0),
#  (55,
#   'Person_22',
#   None,
#   'HaarCascade',
#   0.8880886910272585,
#   None,
#   None,
#   None,
#   0),
#  (56, 'Person_22', None, 'DNN', 0.7052832117144201, None, None, None, 0),
#  (57,
#   'Person_23',
#   None,
#   'HaarCascade',
#   0.6758892372225868,
#   None,
#   None,
#   None,
#   0),
#  (58, 'Person_23', None, 'DNN', 0.9671662911349141, None, None, None, 0),
#  (59,
#   'Person_24',
#   None,
#   'HaarCascade',
#   0.4828347761806165,
#   None,
#   None,
#   None,
#   0),
#  (60, 'Person_24', None, 'DNN', 0.8827845521175813, None, None, None, 0),
#  (61,
#   'Person_25',
#   None,
#   'HaarCascade',
#   0.6649572188320534,
#   None,
#   None,
#   None,
#   0),
#  (62, 'Person_25', None, 'DNN', 0.7711835234854402, None, None, None, 0),
#  (63,
#   'Person_26',
#   None,
#   'HaarCascade',
#   0.7867290540806032,
#   None,
#   None,
#   None,
#   0),
#  (64, 'Person_26', None, 'DNN', 0.9988603392815405, None, None, None, 0),
#  (65,
#   'Person_27',
#   None,
#   'HaarCascade',
#   0.7753791409455149,
#   None,
#   None,
#   None,
#   0),
#  (66, 'Person_27', None, 'DNN', 0.8963821774043792, None, None, None, 0),
#  (67,
#   'Person_28',
#   None,
#   'HaarCascade',
#   0.8346742809202918,
#   None,
#   None,
#   None,
#   0),
#  (68, 'Person_28', None, 'DNN', 0.9213315860232398, None, None, None, 0),
#  (69,
#   'Person_29',
#   None,
#   'HaarCascade',
#   0.6322039153592532,
#   None,
#   None,
#   None,
#   0),
#  (70, 'Person_29', None, 'DNN', 0.8814041344880573, None, None, None, 0),
#  (71,
#   'Person_30',
#   None,
#   'HaarCascade',
#   0.4567744295378082,
#   None,
#   None,
#   None,
#   0),
#  (72, 'Person_30', None, 'DNN', 0.7721046366341069, None, None, None, 0),
#  (73,
#   'Person_31',
#   None,
#   'HaarCascade',
#   0.5097335835316116,
#   None,
#   None,
#   None,
#   0),
#  (74, 'Person_31', None, 'DNN', 0.7443566412759619, None, None, None, 0),
#  (75,
#   'Person_32',
#   None,
#   'HaarCascade',
#   0.6415871204983048,
#   None,
#   None,
#   None,
#   0),
#  (76, 'Person_32', None, 'DNN', 0.807190146051266, None, None, None, 0),
#  (77,
#   'Person_33',
#   None,
#   'HaarCascade',
#   0.8613537441360938,
#   None,
#   None,
#   None,
#   0),
#  (78, 'Person_33', None, 'DNN', 0.8381704308661588, None, None, None, 0),
#  (79,
#   'Person_34',
#   None,
#   'HaarCascade',
#   0.6935055075671339,
#   None,
#   None,
#   None,
#   0),
#  (80, 'Person_34', None, 'DNN', 0.7807348388960661, None, None, None, 0),
#  (81,
#   'Person_35',
#   None,
#   'HaarCascade',
#   0.5093169799928761,
#   None,
#   None,
#   None,
#   0),
#  (82, 'Person_35', None, 'DNN', 0.9820341269638171, None, None, None, 0),
#  (83,
#   'Person_36',
#   None,
#   'HaarCascade',
#   0.5779968098470414,
#   None,
#   None,
#   None,
#   0),
#  (84, 'Person_36', None, 'DNN', 0.9998143739538019, None, None, None, 0),
#  (85,
#   'Person_37',
#   None,
#   'HaarCascade',
#   0.45505029922335155,
#   None,
#   None,
#   None,
#   0),
#  (86, 'Person_37', None, 'DNN', 0.9713992039464263, None, None, None, 0),
#  (87,
#   'Person_38',
#   None,
#   'HaarCascade',
#   0.41087392579301546,
#   None,
#   None,
#   None,
#   0),
#  (88, 'Person_38', None, 'DNN', 0.9151688831978617, None, None, None, 0),
#  (89,
#   'Person_39',
#   None,
#   'HaarCascade',
#   0.7977572886802066,
#   None,
#   None,
#   None,
#   0),
#  (90, 'Person_39', None, 'DNN', 0.8386438190506498, None, None, None, 0),
#  (91,
#   'Person_40',
#   None,
#   'HaarCascade',
#   0.6452195208453766,
#   None,
#   None,
#   None,
#   0),
#  (92, 'Person_40', None, 'DNN', 0.9160276562485266, None, None, None, 0),
#  (93,
#   'Person_41',
#   None,
#   'HaarCascade',
#   0.5167954955917122,
#   None,
#   None,
#   None,
#   0),
#  (94, 'Person_41', None, 'DNN', 0.835310449960432, None, None, None, 0),
#  (95,
#   'Person_42',
#   None,
#   'HaarCascade',
#   0.47301053759467016,
#   None,
#   None,
#   None,
#   0),
#  (96, 'Person_42', None, 'DNN', 0.712249277363089, None, None, None, 0),
#  (97,
#   'Person_43',
#   None,
#   'HaarCascade',
#   0.6070599011028796,
#   None,
#   None,
#   None,
#   0),
#  (98, 'Person_43', None, 'DNN', 0.8231301892367988, None, None, None, 0),
#  (99,
#   'Person_44',
#   None,
#   'HaarCascade',
#   0.571355708637429,
#   None,
#   None,
#   None,
#   0),
#  (100, 'Person_44', None, 'DNN', 0.7322437959608883, None, None, None, 0),
#  (101,
#   'Person_45',
#   None,
#   'HaarCascade',
#   0.5187282593947597,
#   None,
#   None,
#   None,
#   0),
#  (102, 'Person_45', None, 'DNN', 0.7945301975352529, None, None, None, 0),
#  (103,
#   'Person_46',
#   None,
#   'HaarCascade',
#   0.856064863476086,
#   None,
#   None,
#   None,
#   0),
#  (104, 'Person_46', None, 'DNN', 0.9826502806736054, None, None, None, 0),
#  (105,
#   'Person_47',
#   None,
#   'HaarCascade',
#   0.5870844390168144,
#   None,
#   None,
#   None,
#   0),
#  (106, 'Person_47', None, 'DNN', 0.9134072798447364, None, None, None, 0),
#  (107,
#   'Person_48',
#   None,
#   'HaarCascade',
#   0.5255324394149679,
#   None,
#   None,
#   None,
#   0),
#  (108, 'Person_48', None, 'DNN', 0.8716255150649533, None, None, None, 0),
#  (109,
#   'Person_49',
#   None,
#   'HaarCascade',
#   0.6249689576422055,
#   None,
#   None,
#   None,
#   0),
#  (110, 'Person_49', None, 'DNN', 0.9241161069280105, None, None, None, 0),
#  (111,
#   'Person_50',
#   None,
#   'HaarCascade',
#   0.418774734702931,
#   None,
#   None,
#   None,
#   0),
#  (112, 'Person_50', None, 'DNN', 0.8376919567055864, None, None, None, 0),
#  (113,
#   'Person_51',
#   None,
#   'HaarCascade',
#   0.641750671894715,
#   None,
#   None,
#   None,
#   0),
#  (114, 'Person_51', None, 'DNN', 0.774865535313585, None, None, None, 0),
#  (115,
#   'Person_52',
#   None,
#   'HaarCascade',
#   0.6647914420296825,
#   None,
#   None,
#   None,
#   0),
#  (116, 'Person_52', None, 'DNN', 0.9347259179843408, None, None, None, 0),
#  (117,
#   'Person_53',
#   None,
#   'HaarCascade',
#   0.5989365179279769,
#   None,
#   None,
#   None,
#   0),
#  (118, 'Person_53', None, 'DNN', 0.8836092842685096, None, None, None, 0),
#  (119,
#   'Person_54',
#   None,
#   'HaarCascade',
#   0.4136378903993256,
#   None,
#   None,
#   None,
#   0),
#  (120, 'Person_54', None, 'DNN', 0.856982897916474, None, None, None, 0),
#  (121,
#   'Person_55',
#   None,
#   'HaarCascade',
#   0.5810984977169062,
#   None,
#   None,
#   None,
#   0),
#  (122, 'Person_55', None, 'DNN', 0.8341054103021937, None, None, None, 0),
#  (123,
#   'Person_56',
#   None,
#   'HaarCascade',
#   0.7809221076904894,
#   None,
#   None,
#   None,
#   0),
#  (124, 'Person_56', None, 'DNN', 0.7159490401237201, None, None, None, 0),
#  (125,
#   'Person_57',
#   None,
#   'HaarCascade',
#   0.41310821686178395,
#   None,
#   None,
#   None,
#   0),
#  (126, 'Person_57', None, 'DNN', 0.8453354185849187, None, None, None, 0),
#  (127,
#   'Person_58',
#   None,
#   'HaarCascade',
#   0.6373257171137693,
#   None,
#   None,
#   None,
#   0),
#  (128, 'Person_58', None, 'DNN', 0.7740999911099632, None, None, None, 0),
#  (129,
#   'Person_59',
#   None,
#   'HaarCascade',
#   0.7264021207618783,
#   None,
#   None,
#   None,
#   0),
#  (130, 'Person_59', None, 'DNN', 0.8028039711134016, None, None, None, 0),
#  (131,
#   'Person_60',
#   None,
#   'HaarCascade',
#   0.891807648144048,
#   None,
#   None,
#   None,
#   0),
#  (132, 'Person_60', None, 'DNN', 0.7320866038033718, None, None, None, 0),
#  (133,
#   'Person_61',
#   None,
#   'HaarCascade',
#   0.44870273455275367,
#   None,
#   None,
#   None,
#   0),
#  (134, 'Person_61', None, 'DNN', 0.7093625929718211, None, None, None, 0),
#  (135,
#   'Person_62',
#   None,
#   'HaarCascade',
#   0.713652962969439,
#   None,
#   None,
#   None,
#   0),
#  (136, 'Person_62', None, 'DNN', 0.7937834978061172, None, None, None, 0),
#  (137,
#   'Person_63',
#   None,
#   'HaarCascade',
#   0.6465383978723063,
#   None,
#   None,
#   None,
#   0),
#  (138, 'Person_63', None, 'DNN', 0.7353163960422305, None, None, None, 0),
#  (139,
#   'Person_64',
#   None,
#   'HaarCascade',
#   0.7119088309608457,
#   None,
#   None,
#   None,
#   0),
#  (140, 'Person_64', None, 'DNN', 0.9773304260089104, None, None, None, 0),
#  (141,
#   'Person_65',
#   None,
#   'HaarCascade',
#   0.8829291079416564,
#   None,
#   None,
#   None,
#   0),
#  (142, 'Person_65', None, 'DNN', 0.7880121331638675, None, None, None, 0),
#  (143,
#   'Person_66',
#   None,
#   'HaarCascade',
#   0.4142795607672417,
#   None,
#   None,
#   None,
#   0),
#  (144, 'Person_66', None, 'DNN', 0.9721196343489096, None, None, None, 0),
#  (145,
#   'Person_67',
#   None,
#   'HaarCascade',
#   0.7094700659009514,
#   None,
#   None,
#   None,
#   0),
#  (146, 'Person_67', None, 'DNN', 0.7092679312947546, None, None, None, 0),
#  (147,
#   'Person_68',
#   None,
#   'HaarCascade',
#   0.8955798710012914,
#   None,
#   None,
#   None,
#   0),
#  (148, 'Person_68', None, 'DNN', 0.76988072153648, None, None, None, 0),
#  (149,
#   'Person_69',
#   None,
#   'HaarCascade',
#   0.6102307099838991,
#   None,
#   None,
#   None,
#   0),
#  (150, 'Person_69', None, 'DNN', 0.704659366750128, None, None, None, 0),
#  (151,
#   'Person_70',
#   None,
#   'HaarCascade',
#   0.6145209028877563,
#   None,
#   None,
#   None,
#   0),
#  (152, 'Person_70', None, 'DNN', 0.7408440826328359, None, None, None, 0),
#  (153,
#   'Person_71',
#   None,
#   'HaarCascade',
#   0.41974500879877225,
#   None,
#   None,
#   None,
#   0),
#  (154, 'Person_71', None, 'DNN', 0.8054511223175265, None, None, None, 0),
#  (155,
#   'Person_72',
#   None,
#   'HaarCascade',
#   0.5133848221207509,
#   None,
#   None,
#   None,
#   0),
#  (156, 'Person_72', None, 'DNN', 0.7531616087075219, None, None, None, 0),
#  (157,
#   'Person_73',
#   None,
#   'HaarCascade',
#   0.8379138022850022,
#   None,
#   None,
#   None,
#   0),
#  (158, 'Person_73', None, 'DNN', 0.8175172951159246, None, None, None, 0),
#  (159,
#   'Person_74',
#   None,
#   'HaarCascade',
#   0.8994918605806379,
#   None,
#   None,
#   None,
#   0),
#  (160, 'Person_74', None, 'DNN', 0.7659383332293102, None, None, None, 0),
#  (161,
#   'Person_75',
#   None,
#   'HaarCascade',
#   0.5868112303826382,
#   None,
#   None,
#   None,
#   0),
#  (162, 'Person_75', None, 'DNN', 0.8879221825741952, None, None, None, 0),
#  (163,
#   'Person_76',
#   None,
#   'HaarCascade',
#   0.43412507195584593,
#   None,
#   None,
#   None,
#   0),
#  (164, 'Person_76', None, 'DNN', 0.7385879313625938, None, None, None, 0),
#  (165,
#   'Person_77',
#   None,
#   'HaarCascade',
#   0.65011502454776,
#   None,
#   None,
#   None,
#   0),
#  (166, 'Person_77', None, 'DNN', 0.7239258606646286, None, None, None, 0),
#  (167,
#   'Person_78',
#   None,
#   'HaarCascade',
#   0.8307899658057321,
#   None,
#   None,
#   None,
#   0),
#  (168, 'Person_78', None, 'DNN', 0.9196270527197492, None, None, None, 0),
#  (169,
#   'Person_79',
#   None,
#   'HaarCascade',
#   0.6596025558865056,
#   None,
#   None,
#   None,
#   0),
#  (170, 'Person_79', None, 'DNN', 0.8214359707310421, None, None, None, 0),
#  (171,
#   'Person_80',
#   None,
#   'HaarCascade',
#   0.5783096538529131,
#   None,
#   None,
#   None,
#   0),
#  (172, 'Person_80', None, 'DNN', 0.9138744367057883, None, None, None, 0),
#  (173,
#   'Person_81',
#   None,
#   'HaarCascade',
#   0.42659740982238165,
#   None,
#   None,
#   None,
#   0),
#  (174, 'Person_81', None, 'DNN', 0.8989281713230524, None, None, None, 0),
#  (175,
#   'Person_82',
#   None,
#   'HaarCascade',
#   0.40053083772333703,
#   None,
#   None,
#   None,
#   0),
#  (176, 'Person_82', None, 'DNN', 0.8826764009720642, None, None, None, 0),
#  (177,
#   'Person_83',
#   None,
#   'HaarCascade',
#   0.8075090951468973,
#   None,
#   None,
#   None,
#   0),
#  (178, 'Person_83', None, 'DNN', 0.9203328104797637, None, None, None, 0),
#  (179,
#   'Person_84',
#   None,
#   'HaarCascade',
#   0.7775646452581535,
#   None,
#   None,
#   None,
#   0),
#  (180, 'Person_84', None, 'DNN', 0.9501347447016355, None, None, None, 0),
#  (181,
#   'Person_85',
#   None,
#   'HaarCascade',
#   0.5479395858413854,
#   None,
#   None,
#   None,
#   0),
#  (182, 'Person_85', None, 'DNN', 0.7544894094729255, None, None, None, 0),
#  (183,
#   'Person_86',
#   None,
#   'HaarCascade',
#   0.47044388872029186,
#   None,
#   None,
#   None,
#   0),
#  (184, 'Person_86', None, 'DNN', 0.7589019707246678, None, None, None, 0),
#  (185,
#   'Person_87',
#   None,
#   'HaarCascade',
#   0.48179151952397303,
#   None,
#   None,
#   None,
#   0),
#  (186, 'Person_87', None, 'DNN', 0.8785853324438533, None, None, None, 0),
#  (187,
#   'Person_88',
#   None,
#   'HaarCascade',
#   0.6266103427192451,
#   None,
#   None,
#   None,
#   0),
#  (188, 'Person_88', None, 'DNN', 0.782792094165023, None, None, None, 0),
#  (189,
#   'Person_89',
#   None,
#   'HaarCascade',
#   0.645351965246659,
#   None,
#   None,
#   None,
#   0),
#  (190, 'Person_89', None, 'DNN', 0.8762170117470183, None, None, None, 0),
#  (191,
#   'Person_90',
#   None,
#   'HaarCascade',
#   0.7595043600827442,
#   None,
#   None,
#   None,
#   0),
#  (192, 'Person_90', None, 'DNN', 0.8230517821102541, None, None, None, 0),
#  (193,
#   'Person_91',
#   None,
#   'HaarCascade',
#   0.8725806268438578,
#   None,
#   None,
#   None,
#   0),
#  (194, 'Person_91', None, 'DNN', 0.9962937263589817, None, None, None, 0),
#  (195,
#   'Person_92',
#   None,
#   'HaarCascade',
#   0.5960956081870332,
#   None,
#   None,
#   None,
#   0),
#  (196, 'Person_92', None, 'DNN', 0.9206940386614675, None, None, None, 0),
#  (197,
#   'Person_93',
#   None,
#   'HaarCascade',
#   0.4556429098567947,
#   None,
#   None,
#   None,
#   0),
#  (198, 'Person_93', None, 'DNN', 0.9978423869048856, None, None, None, 0),
#  (199,
#   'Person_94',
#   None,
#   'HaarCascade',
#   0.7744921811440573,
#   None,
#   None,
#   None,
#   0),
#  (200, 'Person_94', None, 'DNN', 0.9367115684673359, None, None, None, 0),
#  (201,
#   'Person_95',
#   None,
#   'HaarCascade',
#   0.5984366805407653,
#   None,
#   None,
#   None,
#   0),
#  (202, 'Person_95', None, 'DNN', 0.9890136575761447, None, None, None, 0),
#  (203,
#   'Person_96',
#   None,
#   'HaarCascade',
#   0.7769963855623255,
#   None,
#   None,
#   None,
#   0),
#  (204, 'Person_96', None, 'DNN', 0.9224865589128887, None, None, None, 0),
#  (205,
#   'Person_97',
#   None,
#   'HaarCascade',
#   0.7846613496788422,
#   None,
#   None,
#   None,
#   0),
#  (206, 'Person_97', None, 'DNN', 0.8320443973231638, None, None, None, 0),
#  (207,
#   'Person_98',
#   None,
#   'HaarCascade',
#   0.7146168267831354,
#   None,
#   None,
#   None,
#   0),
#  (208, 'Person_98', None, 'DNN', 0.9195504415222949, None, None, None, 0),
#  (209,
#   'Person_99',
#   None,
#   'HaarCascade',
#   0.7085301874994392,
#   None,
#   None,
#   None,
#   0),
#  (210, 'Person_99', None, 'DNN', 0.9323290796252188, None, None, None, 0),
#  (211,
#   'Joseph_Blatter',
#   '2025-02-27T07:20:00',
#   'DNN',
#   0.8695418107896754,
#   20,
#   None,
#   None,
#   0),
#  (212,
#   'Joseph_Blatter',
#   '2025-02-27T12:30:00',
#   'Clock-Out',
#   None,
#   20,
#   None,
#   None,
#   0),
#  (213,
#   'Joseph_Blatter',
#   '2025-02-27T13:30:00',
#   'DNN',
#   0.9930016158760233,
#   0,
#   None,
#   None,
#   0),
#  (214,
#   'Joseph_Blatter',
#   '2025-02-27T17:00:00',
#   'Clock-Out',
#   None,
#   0,
#   None,
#   None,
#   0),
#  (215,
#   'Oleg_Romantsev',
#   '2025-02-27T07:44:00',
#   'DNN',
#   0.7011853129243854,
#   44,
#   None,
#   None,
#   0),
#  (216,
#   'Oleg_Romantsev',
#   '2025-02-27T12:30:00',
#   'Clock-Out',
#   None,
#   44,
#   None,
#   None,
#   0),
#  (217,
#   'Oleg_Romantsev',
#   '2025-02-27T13:52:00',
#   'DNN',
#   0.7508608266341021,
#   22,
#   None,
#   None,
#   0),
#  (218,
#   'Oleg_Romantsev',
#   '2025-02-27T17:00:00',
#   'Clock-Out',
#   None,
#   22,
#   None,
#   None,
#   0),
#  (219,
#   'Nelson_Acosta',
#   '2025-02-27T07:00:00',
#   'DNN',
#   0.9226207655357561,
#   0,
#   None,
#   None,
#   0),
#  (220,
#   'Nelson_Acosta',
#   '2025-02-27T12:30:00',
#   'Clock-Out',
#   None,
#   0,
#   None,
#   None,
#   0),
#  (221,
#   'Nelson_Acosta',
#   '2025-02-27T13:30:00',
#   'DNN',
#   0.7915244447861258,
#   0,
#   None,
#   None,
#   0),
#  (222,
#   'Nelson_Acosta',
#   '2025-02-27T17:00:00',
#   'Clock-Out',
#   None,
#   0,
#   None,
#   None,
#   0)]

# %% [markdown]
# # Visualize Simulation Model Performance.

# %%
visualize_accuracy(db_manager)

# %% [markdown]
# # Determining the best-performing model.
#
# - (Haar cascades vs. OpenCV DNN), we compare their face detection accuracy using confidence scores stored in the SQLite database. The key evaluation metrics include:
#
# ### 1. Detection Confidence Scores:
#
# - Each clock-in/out attempt logs the confidence score of the detected face.
#
# - The higher the average confidence score, the better the model.
#
# ### 2. False Positives & False Negatives:
#
# - If a model detects a face when there is none (false positive), it's unreliable.
#
# - If a model fails to detect a face when there is one (false negative), it's unreliable.
#
# ### 3. Detection Speed:
#
# - Haar cascades are faster but less accurate.
#
# - OpenCV DNN is slower but more accurate.
#
# ### 4. Consistency Across Multiple Tests:
#
# - The model that consistently provides high confidence scores and fewer errors over many clock-ins/outs is considered the best.

# %%
def check_existing_tables():
    """
    Check how many tables we have in our database.
    """
    conn = sqlite3.connect("attendance.db")
    cursor = conn.cursor()
    
    cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
    tables = cursor.fetchall()
    
    conn.close()
    
    print("Existing tables:", tables)

# Check available tables
check_existing_tables()
# Out:
# Existing tables: [('attendance_log',), ('sqlite_sequence',), ('attendance',)]

# %% [markdown]
# ### Extract confidence scores

# %%
def fetch_confidence_scores():
    """Fetch confidence scores, excluding clock-out rows."""
    conn = sqlite3.connect("attendance.db")
    query = "SELECT model, confidence FROM attendance WHERE model NOT LIKE 'Clock-Out'"
    df = pd.read_sql(query, conn)
    conn.close()
    
    return df

# %%
# Load data
df_scores = fetch_confidence_scores()

df_scores
# Out:
#            model  confidence
# 0    HaarCascade    0.404183
# 1            DNN    0.872460
# 2    HaarCascade    0.699678
# 3            DNN    0.951530
# 4    HaarCascade    0.792712
# ..           ...         ...
# 211          DNN    0.993002
# 212          DNN    0.701185
# 213          DNN    0.750861
# 214          DNN    0.922621
# 215          DNN    0.791524
#
# [216 rows x 2 columns]

# %% [markdown]
# ### Compare Average Confidence Scores.

# %%
# Compute average confidence for each model
avg_scores = df_scores.groupby("model")["confidence"].mean()

print("Average Confidence Scores:")
print(avg_scores)

# Plot comparison
plt.figure(figsize=(8,5))
avg_scores.plot(kind="bar", color=["blue", "green"])

plt.xlabel("Model")
plt.ylabel("Average Confidence Score")
plt.title("Model Accuracy Comparison (Haar vs. OpenCV DNN)")
plt.ylim(0, 1)

plt.show()
# Out:
# Average Confidence Scores:
# model
# DNN            0.844946
# HaarCascade    0.642058
# Name: confidence, dtype: float64

# %% [markdown]
# ### Comparison Results.
#
# - OpenCV DNN has a higher average confidence score 0.846 compared to 0.648 of Haar Cascade.
#
# - OpenCV DNN consistently outperforms Haar cascades, which means it is the better model.

# %% [markdown]
# # Analyze False Detections.

# %%
def analyze_false_detections():
    """
    Check false detections by filtering low confidence scores.
    """
    threshold = 0.5  # Below 50% confidence is considered unreliable
    false_detections = df_scores[df_scores["confidence"] < threshold]
    
    print(f"Total False Detections:\n{false_detections['model'].value_counts()}")
    
    # Plot false detections
    plt.figure(figsize=(8,5))
    false_detections["model"].value_counts().plot(kind="bar", color=["red", "orange"])
    
    plt.xlabel("Model")
    plt.ylabel("False Detections Count")
    plt.title("False Detections Comparison (Haar vs. OpenCV DNN)")
    
    plt.show()

# %%
analyze_false_detections()
# Out:
# Total False Detections:
# model
# HaarCascade    23
# Name: count, dtype: int64

# %% [markdown]
# ## Detection Results.
#
# - Haar cascade has more false detections (lower confidence scores).
#
# - OpenCV DNN has no false positives/negatives, making it more reliable.
